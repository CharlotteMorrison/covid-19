# %%
import json

with open('datasets/biorxiv_medrxiv/biorxiv_medrxiv/0a43046c154d0e521a6c425df215d90f3c62681e.json') as f:
    article = json.load(f)
print(json.dumps(article, indent = 4))
# Out:
# {
#     "paper_id": "0a43046c154d0e521a6c425df215d90f3c62681e",
#     "metadata": {
#         "title": "Full Title: Comparisons of a Novel Air Sampling Filter Material, Wash Buffers and 2 Extraction Methods in the Detection and Quantification of Influenza Virus 3 Short title: Comparisons of Air Sampling Filter Materials for the Detection Quantification 4 of Influenza Virus CPUB-Occup & Environ Hea",
#         "authors": [
#             {
#                 "first": "Terrance",
#                 "middle": [
#                     "A"
#                 ],
#                 "last": "Thedell",
#                 "suffix": "",
#                 "affiliation": {},
#                 "email": ""
#             },
#             {
#                 "first": "Corey",
#                 "middle": [
#                     "L"
#                 ],
#                 "last": "Boles",
#                 "suffix": "",
#                 "affiliation": {},
#                 "email": ""
#             },
# ...
